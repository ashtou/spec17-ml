# %% [markdown]
# # 1. Neural Networks Models
#
# We have developed `adam` models with three hidden layers of (12,12,12), (16,16,16) [[Das et al.](https://dl.acm.org/doi/abs/10.1145/3185768.3186301)], (50,100,50) [[Lopez et al.](https://ieeexplore.ieee.org/document/8614157)], and (100, 100, 100) [[Wang et al.](https://dl.acm.org/doi/10.1145/3284127)] with the maximum 10000 iterations (which determines the number of epochs), and early stopping enabled.
#
# **Note**: The SPEC datasets, the development frameworks, and the exact features used in these studies are not the same as ours, but we have attempted to replicate their models as closely as possible.

# %%
# %reset -f

#####
# restore the notebook session
import dill

dill.load_session("pickles/regress_02_fs_rfe_mask.pkl")

warnings.simplefilter(action="default")
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

from sklearn.model_selection import GridSearchCV
from predict import visualise

# eli5 PermutationImportance with fs_MLP_adam

est = fs_pi_mlp_adam
# e_ind of adam is 5
e_ind = 5

param_grid[e_ind] = {
    "eval__regressor__hidden_layer_sizes": [
        (10,),
        (20,),
        (30,),
        (50,),
        (12,12,12),
        (16,16,16),
        (50,100,50),
        (100,100,100)
    ],
}

PARALLEL = False
grid = {}

if PARALLEL:
    print(colored("Parallel Computation", "red"))
# display pipeline
set_config(display="diagram")

pipe.steps.pop(-1) 
pipe.steps.pop(-1) 

for suite in suites:
    cat = suite["name"]
    print(colored("\n***** " + cat + " *****", "magenta", attrs=["bold"]))

    grid[cat] = {}

    pipe.steps.pop(-1) 

    
    evaluate = est.estimator
    print("Regressor:", colored(visualise.get_estimator_label(est), "green")) 

    
    pipe.steps.extend([
        ("eval", evaluate)
    ])
    #display(pipe)
    print("Pipeline Steps: " + str(list(pipe.named_steps)))

    #####
    # Grid Search CV
    grid[cat][e_ind] = GridSearchCV(
        pipe,
        param_grid=param_grid[e_ind],
        scoring=[GRIDCV_SCORING, "r2"],
        n_jobs= GRIDCV_N_JOBS if PARALLEL else None,
        cv=k_fold,
        # for multi-metric evaluation, refit should be the scorer to be used for best_params_, etc
        refit=GRIDCV_SCORING, # refit=True,
        verbose=True,
        return_train_score = True 
    )

    # fit
    grid[cat][e_ind].fit(train_X_df[cat], train_y_df[cat])

    # print("check rfe_mask_fs support mask:\n", grid[cat][e_ind].best_estimator_["rfe_mask_fs"].get_support())
    print(
        "Best cross-validation MAE: {:.4f}".format(-grid[cat][e_ind].best_score_)
    )
    # because it has been refit before, we can get score on the test too
    print(
        "Best MAE on Test: {:.4f}".format(
            -grid[cat][e_ind].score(test_X_df[cat], test_y_df[cat])
        )
    )
    print("Best parameters: {}\n".format(grid[cat][e_ind].best_params_))
    

display(pipe)

#####
# save the notebook session
dill.dump_session("pickles/regress_related_work.pkl")
# Out:
# ***** FP_rate *****
# Regressor: Permutation_MLPRegressor_adam
# Pipeline Steps: ['transform_X', 'reorder_X', 'debug1', 'scale', 'debug2', 'variance_fs', 'eval']
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:  2.1min finished
# Best cross-validation MAE: 20.7144
# Best MAE on Test: 17.0333
# Best parameters: {'eval__regressor__hidden_layer_sizes': (100, 100, 100)}
#
#
# ***** FP_speed *****
# Regressor: Permutation_MLPRegressor_adam
# Pipeline Steps: ['transform_X', 'reorder_X', 'debug1', 'scale', 'debug2', 'variance_fs', 'eval']
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:  1.9min finished
# Best cross-validation MAE: 10.6143
# Best MAE on Test: 9.9045
# Best parameters: {'eval__regressor__hidden_layer_sizes': (100, 100, 100)}
#
#
# ***** Int_rate *****
# Regressor: Permutation_MLPRegressor_adam
# Pipeline Steps: ['transform_X', 'reorder_X', 'debug1', 'scale', 'debug2', 'variance_fs', 'eval']
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:  2.3min finished
# Best cross-validation MAE: 19.0922
# Best MAE on Test: 14.8508
# Best parameters: {'eval__regressor__hidden_layer_sizes': (100, 100, 100)}
#
#
# ***** Int_speed *****
# Regressor: Permutation_MLPRegressor_adam
# Pipeline Steps: ['transform_X', 'reorder_X', 'debug1', 'scale', 'debug2', 'variance_fs', 'eval']
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:  1.9min finished
# Best cross-validation MAE: 0.3519
# Best MAE on Test: 0.3573
# Best parameters: {'eval__regressor__hidden_layer_sizes': (100, 100, 100)}
# Pipeline(steps=[('transform_X',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('log_trans_feat',
#                                                   FunctionTransformer(func=<ufunc 'log'>),
#                                                   ['cpus', 'mem_kb',
#                                                    'threads_or_copies'])])),
#                 ('reorder_X',
#                  ColumnReorder(initial_features=['nominal_mhz', 'max_mhz',
#                                                  'cpus', 'threads_per_core',
#                                                  'cores_per_socket', 'sockets',
#                                                  'numas', 'l1d_cache_kb',
#                                                  'l1i_cache_kb', 'l...
#                                trans_features=['cpus', 'mem_kb',
#                                                'threads_or_copies'])),
#                 ('debug1', Debug()), ('scale', StandardScaler()),
#                 ('debug2', Debug()),
#                 ('variance_fs', VarianceThreshold(threshold=0)),
#                 ('eval',
#                  CustomTransformedTargetRegressor(regressor=MLPRegressor(activation='tanh',
#                                                                          early_stopping=True,
#                                                                          hidden_layer_sizes=(20,),
#                                                                          max_iter=10000,
#                                                                          random_state=42,
#                                                                          tol=0.001),
#                                                   trans_y='log'))])

# %% [markdown]
# # 2. Evaluation of Related Work
#
# ## 2.1 Exploring GridSearchCV Results
#
# It is observed that models with the hidden layer size of (100, 100, 100) perform better than our top-performing `adam` model, and provide the best average CV MAE across all four suites, but they cannot still reach the accuracy of our final `lbfgs` models (refer to the paper for a more detailed discussion).

# %%
# %reset -f

#####
# restore the notebook session
import dill

dill.load_session("pickles/regress_related_work.pkl")

warnings.simplefilter(action="default")

pd.set_option("display.max_columns", None)  # show all columns when display
pd.set_option("display.max_rows", None)

for suite in suites:
    cat = suite["name"]
    print(colored("\n***** " + cat + " *****", "magenta", attrs=["bold"]))
    print("GridSearchCV Regressor:", colored(visualise.get_estimator_label(est), "green")) 

    gs_df = pd.concat(
        [pd.DataFrame(grid[cat][e_ind].cv_results_["params"]),
        # use "mean_test_score" for single metric evaluation
        pd.DataFrame(grid[cat][e_ind].cv_results_["mean_train_r2"], columns=["Avg. CV Train R2"]),
        pd.DataFrame(grid[cat][e_ind].cv_results_["mean_test_r2"], columns=["Avg. CV Test R2"]),
        pd.DataFrame(-grid[cat][e_ind].cv_results_["mean_train_neg_mean_absolute_error"], columns=["Avg. CV Train MAE"]),
        pd.DataFrame(-grid[cat][e_ind].cv_results_["mean_test_neg_mean_absolute_error"], columns=["Avg. CV Test MAE"]),
        pd.DataFrame(grid[cat][e_ind].cv_results_["mean_score_time"], columns=["mean score time"]),
        pd.DataFrame(grid[cat][e_ind].cv_results_["mean_fit_time"], columns=["mean fit time"])
        ],
        axis=1)
    gs_df = gs_df.sort_values(by=['Avg. CV Test MAE'], ascending=True)
    
    # style the dateframe
    def f(dat, c="green"):
        return [f'background-color: {c}' for i in dat]

    display(gs_df.head(15).style.apply(f, axis=0, subset=["Avg. CV Test MAE", "mean score time"]))
    regr_model = model_regress.RegrModel("grid_best regr_model", grid[cat][e_ind].best_estimator_)

    # regr_model.fit(train_X_df[cat], train_y_df[cat])
    # regr_model.predict(test_X_df[cat], test_y_df[cat])
    # print(regr_model)
# Out:
# ***** FP_rate *****
# GridSearchCV Regressor: Permutation_MLPRegressor_adam
# <style  type="text/css" >
#     #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row0_col4 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row0_col5 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row1_col4 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row1_col5 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row2_col4 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row2_col5 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row3_col4 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row3_col5 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row4_col4 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row4_col5 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row5_col4 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row5_col5 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row6_col4 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row6_col5 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row7_col4 {
#             background-color:  green;
#         }    #T_ef0cbb74_1919_11eb_9586_3d2647e68f44row7_col5 {
#             background-color:  green;
#         }</style><table id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >eval__regressor__hidden_layer_sizes</th>        <th class="col_heading level0 col1" >Avg. CV Train R2</th>        <th class="col_heading level0 col2" >Avg. CV Test R2</th>        <th class="col_heading level0 col3" >Avg. CV Train MAE</th>        <th class="col_heading level0 col4" >Avg. CV Test MAE</th>        <th class="col_heading level0 col5" >mean score time</th>        <th class="col_heading level0 col6" >mean fit time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44level0_row0" class="row_heading level0 row0" >7</th>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row0_col0" class="data row0 col0" >(100, 100, 100)</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row0_col1" class="data row0 col1" >0.874008</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row0_col2" class="data row0 col2" >0.892845</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row0_col3" class="data row0 col3" >19.848528</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row0_col4" class="data row0 col4" >20.714375</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row0_col5" class="data row0 col5" >0.041521</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row0_col6" class="data row0 col6" >6.621434</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44level0_row1" class="row_heading level0 row1" >6</th>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row1_col0" class="data row1 col0" >(50, 100, 50)</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row1_col1" class="data row1 col1" >0.848982</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row1_col2" class="data row1 col2" >0.875575</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row1_col3" class="data row1 col3" >23.657590</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row1_col4" class="data row1 col4" >24.541118</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row1_col5" class="data row1 col5" >0.028037</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row1_col6" class="data row1 col6" >6.665019</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row2_col0" class="data row2 col0" >(50,)</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row2_col1" class="data row2 col1" >0.929866</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row2_col2" class="data row2 col2" >0.862296</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row2_col3" class="data row2 col3" >24.351562</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row2_col4" class="data row2 col4" >26.007584</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row2_col5" class="data row2 col5" >0.018820</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row2_col6" class="data row2 col6" >2.620668</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44level0_row3" class="row_heading level0 row3" >2</th>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row3_col0" class="data row3 col0" >(30,)</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row3_col1" class="data row3 col1" >0.920376</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row3_col2" class="data row3 col2" >0.858323</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row3_col3" class="data row3 col3" >26.598838</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row3_col4" class="data row3 col4" >28.660537</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row3_col5" class="data row3 col5" >0.014091</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row3_col6" class="data row3 col6" >2.596445</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44level0_row4" class="row_heading level0 row4" >1</th>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row4_col0" class="data row4 col0" >(20,)</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row4_col1" class="data row4 col1" >0.900722</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row4_col2" class="data row4 col2" >0.850441</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row4_col3" class="data row4 col3" >29.748388</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row4_col4" class="data row4 col4" >31.240071</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row4_col5" class="data row4 col5" >0.008518</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row4_col6" class="data row4 col6" >1.089145</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44level0_row5" class="row_heading level0 row5" >0</th>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row5_col0" class="data row5 col0" >(10,)</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row5_col1" class="data row5 col1" >0.779076</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row5_col2" class="data row5 col2" >0.800638</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row5_col3" class="data row5 col3" >30.862707</td>
#                         <td id="T_ef0cbb74_1919_11eb_9586_3d2647e68f44row5_col4" class="data row5 col4" >31.248572</td>
# ***** FP_speed *****
# GridSearchCV Regressor: Permutation_MLPRegressor_adam
# <style  type="text/css" >
#     #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row0_col4 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row0_col5 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row1_col4 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row1_col5 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row2_col4 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row2_col5 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row3_col4 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row3_col5 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row4_col4 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row4_col5 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row5_col4 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row5_col5 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row6_col4 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row6_col5 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row7_col4 {
#             background-color:  green;
#         }    #T_ef0cbb75_1919_11eb_9586_3d2647e68f44row7_col5 {
#             background-color:  green;
#         }</style><table id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >eval__regressor__hidden_layer_sizes</th>        <th class="col_heading level0 col1" >Avg. CV Train R2</th>        <th class="col_heading level0 col2" >Avg. CV Test R2</th>        <th class="col_heading level0 col3" >Avg. CV Train MAE</th>        <th class="col_heading level0 col4" >Avg. CV Test MAE</th>        <th class="col_heading level0 col5" >mean score time</th>        <th class="col_heading level0 col6" >mean fit time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44level0_row0" class="row_heading level0 row0" >7</th>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row0_col0" class="data row0 col0" >(100, 100, 100)</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row0_col1" class="data row0 col1" >0.919038</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row0_col2" class="data row0 col2" >0.913885</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row0_col3" class="data row0 col3" >10.239993</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row0_col4" class="data row0 col4" >10.614286</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row0_col5" class="data row0 col5" >0.032238</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row0_col6" class="data row0 col6" >5.900388</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44level0_row1" class="row_heading level0 row1" >6</th>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row1_col0" class="data row1 col0" >(50, 100, 50)</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row1_col1" class="data row1 col1" >0.912535</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row1_col2" class="data row1 col2" >0.907152</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row1_col3" class="data row1 col3" >10.839875</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row1_col4" class="data row1 col4" >11.209771</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row1_col5" class="data row1 col5" >0.025842</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row1_col6" class="data row1 col6" >5.044334</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row2_col0" class="data row2 col0" >(50,)</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row2_col1" class="data row2 col1" >0.881402</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row2_col2" class="data row2 col2" >0.868265</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row2_col3" class="data row2 col3" >12.177838</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row2_col4" class="data row2 col4" >12.610873</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row2_col5" class="data row2 col5" >0.015442</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row2_col6" class="data row2 col6" >2.218809</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44level0_row3" class="row_heading level0 row3" >2</th>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row3_col0" class="data row3 col0" >(30,)</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row3_col1" class="data row3 col1" >0.879732</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row3_col2" class="data row3 col2" >0.867319</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row3_col3" class="data row3 col3" >12.551703</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row3_col4" class="data row3 col4" >13.001403</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row3_col5" class="data row3 col5" >0.010667</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row3_col6" class="data row3 col6" >1.525946</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44level0_row4" class="row_heading level0 row4" >0</th>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row4_col0" class="data row4 col0" >(10,)</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row4_col1" class="data row4 col1" >0.860105</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row4_col2" class="data row4 col2" >0.850243</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row4_col3" class="data row4 col3" >13.462606</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row4_col4" class="data row4 col4" >13.731442</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row4_col5" class="data row4 col5" >0.005570</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row4_col6" class="data row4 col6" >2.732635</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44level0_row5" class="row_heading level0 row5" >1</th>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row5_col0" class="data row5 col0" >(20,)</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row5_col1" class="data row5 col1" >0.853045</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row5_col2" class="data row5 col2" >0.843266</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row5_col3" class="data row5 col3" >13.911186</td>
#                         <td id="T_ef0cbb75_1919_11eb_9586_3d2647e68f44row5_col4" class="data row5 col4" >14.326774</td>
# ***** Int_rate *****
# GridSearchCV Regressor: Permutation_MLPRegressor_adam
# <style  type="text/css" >
#     #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row0_col4 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row0_col5 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row1_col4 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row1_col5 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row2_col4 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row2_col5 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row3_col4 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row3_col5 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row4_col4 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row4_col5 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row5_col4 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row5_col5 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row6_col4 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row6_col5 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row7_col4 {
#             background-color:  green;
#         }    #T_ef0cbb76_1919_11eb_9586_3d2647e68f44row7_col5 {
#             background-color:  green;
#         }</style><table id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >eval__regressor__hidden_layer_sizes</th>        <th class="col_heading level0 col1" >Avg. CV Train R2</th>        <th class="col_heading level0 col2" >Avg. CV Test R2</th>        <th class="col_heading level0 col3" >Avg. CV Train MAE</th>        <th class="col_heading level0 col4" >Avg. CV Test MAE</th>        <th class="col_heading level0 col5" >mean score time</th>        <th class="col_heading level0 col6" >mean fit time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44level0_row0" class="row_heading level0 row0" >7</th>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row0_col0" class="data row0 col0" >(100, 100, 100)</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row0_col1" class="data row0 col1" >0.873936</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row0_col2" class="data row0 col2" >0.881968</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row0_col3" class="data row0 col3" >18.445628</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row0_col4" class="data row0 col4" >19.092234</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row0_col5" class="data row0 col5" >0.039232</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row0_col6" class="data row0 col6" >6.005681</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44level0_row1" class="row_heading level0 row1" >3</th>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row1_col0" class="data row1 col0" >(50,)</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row1_col1" class="data row1 col1" >0.929150</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row1_col2" class="data row1 col2" >0.905838</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row1_col3" class="data row1 col3" >21.010074</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row1_col4" class="data row1 col4" >22.216176</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row1_col5" class="data row1 col5" >0.024743</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row1_col6" class="data row1 col6" >4.248539</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44level0_row2" class="row_heading level0 row2" >6</th>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row2_col0" class="data row2 col0" >(50, 100, 50)</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row2_col1" class="data row2 col1" >0.844582</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row2_col2" class="data row2 col2" >0.853981</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row2_col3" class="data row2 col3" >21.559497</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row2_col4" class="data row2 col4" >22.221695</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row2_col5" class="data row2 col5" >0.033547</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row2_col6" class="data row2 col6" >5.692762</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44level0_row3" class="row_heading level0 row3" >2</th>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row3_col0" class="data row3 col0" >(30,)</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row3_col1" class="data row3 col1" >0.910919</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row3_col2" class="data row3 col2" >0.902549</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row3_col3" class="data row3 col3" >23.054806</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row3_col4" class="data row3 col4" >23.561819</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row3_col5" class="data row3 col5" >0.017476</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row3_col6" class="data row3 col6" >3.339060</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44level0_row4" class="row_heading level0 row4" >1</th>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row4_col0" class="data row4 col0" >(20,)</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row4_col1" class="data row4 col1" >0.929345</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row4_col2" class="data row4 col2" >0.920805</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row4_col3" class="data row4 col3" >24.073287</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row4_col4" class="data row4 col4" >24.649165</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row4_col5" class="data row4 col5" >0.010240</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row4_col6" class="data row4 col6" >1.279861</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44level0_row5" class="row_heading level0 row5" >0</th>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row5_col0" class="data row5 col0" >(10,)</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row5_col1" class="data row5 col1" >0.853644</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row5_col2" class="data row5 col2" >0.885217</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row5_col3" class="data row5 col3" >26.821947</td>
#                         <td id="T_ef0cbb76_1919_11eb_9586_3d2647e68f44row5_col4" class="data row5 col4" >26.630339</td>
# ***** Int_speed *****
# GridSearchCV Regressor: Permutation_MLPRegressor_adam
# <style  type="text/css" >
#     #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row0_col4 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row0_col5 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row1_col4 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row1_col5 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row2_col4 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row2_col5 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row3_col4 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row3_col5 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row4_col4 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row4_col5 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row5_col4 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row5_col5 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row6_col4 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row6_col5 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row7_col4 {
#             background-color:  green;
#         }    #T_ef0cbb77_1919_11eb_9586_3d2647e68f44row7_col5 {
#             background-color:  green;
#         }</style><table id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >eval__regressor__hidden_layer_sizes</th>        <th class="col_heading level0 col1" >Avg. CV Train R2</th>        <th class="col_heading level0 col2" >Avg. CV Test R2</th>        <th class="col_heading level0 col3" >Avg. CV Train MAE</th>        <th class="col_heading level0 col4" >Avg. CV Test MAE</th>        <th class="col_heading level0 col5" >mean score time</th>        <th class="col_heading level0 col6" >mean fit time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44level0_row0" class="row_heading level0 row0" >7</th>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row0_col0" class="data row0 col0" >(100, 100, 100)</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row0_col1" class="data row0 col1" >0.925887</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row0_col2" class="data row0 col2" >0.913549</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row0_col3" class="data row0 col3" >0.328728</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row0_col4" class="data row0 col4" >0.351869</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row0_col5" class="data row0 col5" >0.027007</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row0_col6" class="data row0 col6" >5.355090</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44level0_row1" class="row_heading level0 row1" >6</th>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row1_col0" class="data row1 col0" >(50, 100, 50)</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row1_col1" class="data row1 col1" >0.912936</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row1_col2" class="data row1 col2" >0.902187</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row1_col3" class="data row1 col3" >0.361039</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row1_col4" class="data row1 col4" >0.380139</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row1_col5" class="data row1 col5" >0.021157</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row1_col6" class="data row1 col6" >3.887036</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row2_col0" class="data row2 col0" >(50,)</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row2_col1" class="data row2 col1" >0.901548</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row2_col2" class="data row2 col2" >0.891561</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row2_col3" class="data row2 col3" >0.391410</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row2_col4" class="data row2 col4" >0.405853</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row2_col5" class="data row2 col5" >0.014801</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row2_col6" class="data row2 col6" >2.354221</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44level0_row3" class="row_heading level0 row3" >2</th>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row3_col0" class="data row3 col0" >(30,)</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row3_col1" class="data row3 col1" >0.890269</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row3_col2" class="data row3 col2" >0.877833</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row3_col3" class="data row3 col3" >0.403586</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row3_col4" class="data row3 col4" >0.417939</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row3_col5" class="data row3 col5" >0.009813</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row3_col6" class="data row3 col6" >1.778901</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44level0_row4" class="row_heading level0 row4" >1</th>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row4_col0" class="data row4 col0" >(20,)</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row4_col1" class="data row4 col1" >0.886596</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row4_col2" class="data row4 col2" >0.878084</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row4_col3" class="data row4 col3" >0.418473</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row4_col4" class="data row4 col4" >0.429396</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row4_col5" class="data row4 col5" >0.009529</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row4_col6" class="data row4 col6" >1.871899</td>
#             </tr>
#             <tr>
#                         <th id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row5_col0" class="data row5 col0" >(16, 16, 16)</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row5_col1" class="data row5 col1" >0.874396</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row5_col2" class="data row5 col2" >0.867434</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row5_col3" class="data row5 col3" >0.446859</td>
#                         <td id="T_ef0cbb77_1919_11eb_9586_3d2647e68f44row5_col4" class="data row5 col4" >0.456085</td>
#                         <
